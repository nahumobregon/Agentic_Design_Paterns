# %%
# Copyright (c) 2025 Marco Fago
#
# This code is licensed under the MIT License.
# See the LICENSE file in the repository for the full license text.
from langchain_core.globals import set_debug
set_debug(True)

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableBranch

# --- Configuration ---
# Ensure your API key environment variable is set (e.g., GOOGLE_API_KEY)
try:
    llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
    print(f"Language model initialized: {llm.model}")
except Exception as e:
    print(f"Error initializing language model: {e}")
    llm = None

# --- Define Simulated Sub-Agent Handlers (equivalent to ADK sub_agents) ---

def booking_handler(request: str) -> str:
    """Simulates the Booking Agent handling a request."""
    print("\n--- DELEGATING TO BOOKING HANDLER ---")
    return f"Booking Handler processed request: '{request}'. Result: Simulated booking action."

def info_handler(request: str) -> str:
    """Simulates the Info Agent handling a request."""
    print("\n--- DELEGATING TO INFO HANDLER ---")
    return f"Info Handler processed request: '{request}'. Result: Simulated information retrieval."

def unclear_handler(request: str) -> str:
    """Handles requests that couldn't be delegated."""
    print("\n--- HANDLING UNCLEAR REQUEST ---")
    return f"Coordinator could not delegate request: '{request}'. Please clarify."

# --- Define Coordinator Router Chain (equivalent to ADK coordinator's instruction) ---
# This chain decides which handler to delegate to.
coordinator_router_prompt = ChatPromptTemplate.from_messages([
    ("system", """Analyze the user's request and determine which specialist handler should process it.
     - If the request is related to booking flights or hotels, output 'booker'.
     - For all other general information questions, output 'info'.
     - If the request is unclear or doesn't fit either category, output 'unclear'.
     ONLY output one word: 'booker', 'info', or 'unclear'."""),
    ("user", "{request}")
])

if llm:
    coordinator_router_chain = coordinator_router_prompt | llm | StrOutputParser()

# --- Define the Delegation Logic (equivalent to ADK's Auto-Flow based on sub_agents) ---
# Use RunnableBranch to route based on the router chain's output.

# Define the branches for the RunnableBranch
branches = {
    "booker": RunnablePassthrough.assign(output=lambda x: booking_handler(x['request']['request'])),
    "info": RunnablePassthrough.assign(output=lambda x: info_handler(x['request']['request'])),
    "unclear": RunnablePassthrough.assign(output=lambda x: unclear_handler(x['request']['request'])),
}

# Create the RunnableBranch. It takes the output of the router chain
# and routes the original input ('request') to the corresponding handler.
delegation_branch = RunnableBranch(
    (lambda x: x['decision'].strip() == 'booker', branches["booker"]), # Added .strip()
    (lambda x: x['decision'].strip() == 'info', branches["info"]),     # Added .strip()
    branches["unclear"] # Default branch for 'unclear' or any other output
)

# Combine the router chain and the delegation branch into a single runnable
# The router chain's output ('decision') is passed along with the original input ('request')
# to the delegation_branch.
coordinator_agent = {
    "decision": coordinator_router_chain,
    "request": RunnablePassthrough()
} | delegation_branch | (lambda x: x['output']) # Extract the final output

# --- Example Usage ---
def main():
    if not llm:
        print("\nSkipping execution due to LLM initialization failure.")
        return

    print("--- Running with a booking request ---")
    request_a = "Book me a flight to London."
    result_a = coordinator_agent.invoke({"request": request_a})
    print(f"Final Result A: {result_a}")

    print("\n--- Running with an info request ---")
    request_b = "What is the capital of Italy?"
    result_b = coordinator_agent.invoke({"request": request_b})
    print(f"Final Result B: {result_b}")

    print("\n--- Running with an unclear request ---")
    request_c = "Tell me about quantum physics."
    result_c = coordinator_agent.invoke({"request": request_c})
    print(f"Final Result C: {result_c}")

if __name__ == "__main__":
    main()
# Out:
# Language model initialized: gemini-2.5-flash
# --- Running with a booking request ---
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "request": "Book me a flight to London."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request>] Entering Chain run with input:
# {
#   "request": "Book me a flight to London."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence] Entering Chain run with input:
# {
#   "request": "Book me a flight to London."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "request": "Book me a flight to London."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: Analyze the user's request and determine which specialist handler should process it.\n     - If the request is related to booking flights or hotels, output 'booker'.\n     - For all other general information questions, output 'info'.\n     - If the request is unclear or doesn't fit either category, output 'unclear'.\n     ONLY output one word: 'booker', 'info', or 'unclear'.\nHuman: Book me a flight to London."
#   ]
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnablePassthrough] Entering Chain run with input:
# {
#   "request": "Book me a flight to London."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnablePassthrough] s] Exiting Chain run with output:
# {
#   "request": "Book me a flight to London."
# }
# [llm/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > llm:ChatGoogleGenerativeAI] [4.88s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "booker",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "model_name": "gemini-2.5-flash",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "booker",
#             "response_metadata": {
#               "finish_reason": "STOP",
#               "model_name": "gemini-2.5-flash",
#               "safety_ratings": [],
#               "model_provider": "google_genai"
#             },
#             "type": "ai",
#             "id": "lc_run--019b2601-656c-7060-b1bb-5d6c32a92f16-0",
#             "usage_metadata": {
#               "input_tokens": 96,
#               "output_tokens": 33,
#               "total_tokens": 129,
#               "input_token_details": {
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "reasoning": 31
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {},
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "booker"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence] [4.89s] Exiting Chain run with output:
# {
#   "output": "booker"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request>] [4.89s] Exiting Chain run with output:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch] Entering Chain run with input:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   }
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": true
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output>] Entering Chain run with input:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output>] Entering Chain run with input:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output> > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   }
# }
#
# --- DELEGATING TO BOOKING HANDLER ---
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output> > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output>] s] Exiting Chain run with output:
# {
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output>] s] Exiting Chain run with output:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   },
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch] s] Exiting Chain run with output:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   },
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "booker",
#   "request": {
#     "request": "Book me a flight to London."
#   },
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# [chain/end] [chain:RunnableSequence] [4.89s] Exiting Chain run with output:
# {
#   "output": "Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action."
# }
# Final Result A: Booking Handler processed request: 'Book me a flight to London.'. Result: Simulated booking action.
#
# --- Running with an info request ---
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "request": "What is the capital of Italy?"
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request>] Entering Chain run with input:
# {
#   "request": "What is the capital of Italy?"
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence] Entering Chain run with input:
# {
#   "request": "What is the capital of Italy?"
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "request": "What is the capital of Italy?"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: Analyze the user's request and determine which specialist handler should process it.\n     - If the request is related to booking flights or hotels, output 'booker'.\n     - For all other general information questions, output 'info'.\n     - If the request is unclear or doesn't fit either category, output 'unclear'.\n     ONLY output one word: 'booker', 'info', or 'unclear'.\nHuman: What is the capital of Italy?"
#   ]
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnablePassthrough] Entering Chain run with input:
# {
#   "request": "What is the capital of Italy?"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnablePassthrough] s] Exiting Chain run with output:
# {
#   "request": "What is the capital of Italy?"
# }
# [llm/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > llm:ChatGoogleGenerativeAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "info",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "model_name": "gemini-2.5-flash",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "info",
#             "response_metadata": {
#               "finish_reason": "STOP",
#               "model_name": "gemini-2.5-flash",
#               "safety_ratings": [],
#               "model_provider": "google_genai"
#             },
#             "type": "ai",
#             "id": "lc_run--019b2601-7887-7751-a957-73df8ac360d2-0",
#             "usage_metadata": {
#               "input_tokens": 96,
#               "output_tokens": 36,
#               "total_tokens": 132,
#               "input_token_details": {
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "reasoning": 35
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {},
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "info"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": "info"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request>] s] Exiting Chain run with output:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": false
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": true
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output>] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output>] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output> > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   }
# }
#
# --- DELEGATING TO INFO HANDLER ---
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output> > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output>] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output>] s] Exiting Chain run with output:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   },
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch] s] Exiting Chain run with output:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   },
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "What is the capital of Italy?"
#   },
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval."
# }
# Final Result B: Info Handler processed request: 'What is the capital of Italy?'. Result: Simulated information retrieval.
#
# --- Running with an unclear request ---
# [chain/start] [chain:RunnableSequence] Entering Chain run with input:
# {
#   "request": "Tell me about quantum physics."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request>] Entering Chain run with input:
# {
#   "request": "Tell me about quantum physics."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence] Entering Chain run with input:
# {
#   "request": "Tell me about quantum physics."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "request": "Tell me about quantum physics."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: Analyze the user's request and determine which specialist handler should process it.\n     - If the request is related to booking flights or hotels, output 'booker'.\n     - For all other general information questions, output 'info'.\n     - If the request is unclear or doesn't fit either category, output 'unclear'.\n     ONLY output one word: 'booker', 'info', or 'unclear'.\nHuman: Tell me about quantum physics."
#   ]
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnablePassthrough] Entering Chain run with input:
# {
#   "request": "Tell me about quantum physics."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnablePassthrough] s] Exiting Chain run with output:
# {
#   "request": "Tell me about quantum physics."
# }
# [llm/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > llm:ChatGoogleGenerativeAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "info",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "model_name": "gemini-2.5-flash",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "info",
#             "response_metadata": {
#               "finish_reason": "STOP",
#               "model_name": "gemini-2.5-flash",
#               "safety_ratings": [],
#               "model_provider": "google_genai"
#             },
#             "type": "ai",
#             "id": "lc_run--019b2601-7bf0-7a00-ab4a-be12305b71e4-0",
#             "usage_metadata": {
#               "input_tokens": 95,
#               "output_tokens": 36,
#               "total_tokens": 131,
#               "input_token_details": {
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "reasoning": 35
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {},
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > parser:StrOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence > parser:StrOutputParser] s] Exiting Parser run with output:
# {
#   "output": "info"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request> > chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": "info"
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableParallel<decision,request>] s] Exiting Chain run with output:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": false
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": true
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output>] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output>] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output> > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   }
# }
#
# --- DELEGATING TO INFO HANDLER ---
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output> > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output> > chain:RunnableParallel<output>] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch > chain:RunnableAssign<output>] s] Exiting Chain run with output:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   },
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableBranch] s] Exiting Chain run with output:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   },
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# [chain/start] [chain:RunnableSequence > chain:RunnableLambda] Entering Chain run with input:
# {
#   "decision": "info",
#   "request": {
#     "request": "Tell me about quantum physics."
#   },
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# [chain/end] [chain:RunnableSequence] s] Exiting Chain run with output:
# {
#   "output": "Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval."
# }
# Final Result C: Info Handler processed request: 'Tell me about quantum physics.'. Result: Simulated information retrieval.
